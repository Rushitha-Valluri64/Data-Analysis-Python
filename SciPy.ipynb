# %%
# !pip install SciPy

# %%
import scipy
from scipy import integrate
result,error = integrate.quad (lambda x:x**2,0,1)
print("Result:",result)
print("Erroe:",error)
# Out:
# Result: 0.33333333333333337
# Erroe: 3.700743415417189e-15

# %%
square=lambda x:x**2
result=square(5)
print("Result:",result)
