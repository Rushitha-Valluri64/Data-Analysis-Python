# %%
#This example uses Python 2.7 and the python-request library.
#With sandbox

from requests import Request, Session
from requests.exceptions import ConnectionError, Timeout, TooManyRedirects
import json

url = 'https://sandbox-api.coinmarketcap.com/v1/cryptocurrency/listings/latest'
parameters = {
  'start':'1',
  'limit':'5000',
  'convert':'USD'
}
headers = {
  'Accepts': 'application/json',
  'X-CMC_PRO_API_KEY': 'b54bcf4d-1bca-4e8e-9a24-22ff2c3d462c',
}

session = Session()
session.headers.update(headers)

try:
  response = session.get(url, params=parameters)
  data = json.loads(response.text)
  print(data)
except (ConnectionError, Timeout, TooManyRedirects) as e:
  print(e)
# Out:
# {'status': {'timestamp': '2024-02-20T06:07:33.457Z', 'error_code': 0, 'error_message': None, 'elapsed': 1, 'credit_count': 1, 'notice': None}, 'data': [{'id': 8812, 'name': 'e7xvklcf8vb', 'symbol': '83zskb280hv', 'slug': '5iqc6sajvr2', 'cmc_rank': 3492, 'num_market_pairs': 5316, 'circulating_supply': 3857, 'total_supply': 2793, 'max_supply': 5723, 'infinite_supply': None, 'last_updated': '2024-02-20T06:07:33.457Z', 'date_added': '2024-02-20T06:07:33.457Z', 'tags': ['urgderdf70m', 'gnsdkqoud2c', 'iee62q70ul', '2iwfnglr1qs', 'oi64qoteo9', '97uxvxlhzx', 'ujkxxkxfrfs', '043obck4e8pk', 'zitlbia4bp8', 'q765pq9kwe'], 'platform': None, 'self_reported_circulating_supply': None, 'self_reported_market_cap': None, 'quote': {'USD': {'price': 0.19696086120043366, 'volume_24h': 5156, 'volume_change_24h': 0.6801879553601407, 'percent_change_1h': 0.15951156850926562, 'percent_change_24h': 0.9988622037929082, 'percent_change_7d': 0.7824902679741206, 'market_cap': 0.8136556035306537, 'market_cap_domina
# ...

# %%
type(data)
# Out:
# dict

# %%
import pandas as pd
norm=pd.json_normalize(data['data'])

# %%
norm
# Out:
#      id         name       symbol         slug  cmc_rank  num_market_pairs  \
# 0  8812  e7xvklcf8vb  83zskb280hv  5iqc6sajvr2      3492              5316
# 1  4787  8yyxsszfduv  bsgj27x2fx6   rxpmesdp8x      3863              1999
# 2  4781  9uy2dr8aqn6  hycung57fel  89zrsdv5s8q      9765              4527
# 3  3806  pegefd0390n   ptwuctijju  6tnhimi815t      8797              7119
# 4  4307  9efvf4ipur9   axyx5iiltb  ahgh70oqpt7      6556               404
# 5  2556  d7980b43lsi  btp43zw0jwt  y1i9k07mz1k      2580               500
# 6  3211  c56f5txuk0w  ov5ufbdnyy8  wwbmyyhn3lg      5335              5758
# 7  9006  1e69s99hf8g   edw3iv4w5a  53f96aidf3w      6527              2831
# 8  9433  borgkosiz0j  kwkd37u9y1h  8tookc8jpc5      6962              9075
# 9   544   ak7nzwzyd8   8l1gtwc59s  ttp76mwvng8      2806              5735
#
#    circulating_supply  total_supply  max_supply infinite_supply  ...  \
# 0                3857          2793        5723            None  ...
# ...

# %%
#This example uses Python 2.7 and the python-request library.
#My API Key

from requests import Request, Session
from requests.exceptions import ConnectionError, Timeout, TooManyRedirects
import json

url = 'https://pro-api.coinmarketcap.com/v1/cryptocurrency/listings/latest'
parameters = {
  'start':'1',
  'limit':'100',
  'convert':'USD'
}
headers = {
  'Accepts': 'application/json',
  'X-CMC_PRO_API_KEY': 'b5740911-0024-4398-849e-0485f7a413f0',
}

session = Session()
session.headers.update(headers)

try:
  response = session.get(url, params=parameters)
  data = json.loads(response.text)
  print(data)
except (ConnectionError, Timeout, TooManyRedirects) as e:
  print(e)
# Out:
# {'status': {'timestamp': '2024-02-20T06:00:49.517Z', 'error_code': 0, 'error_message': None, 'elapsed': 23, 'credit_count': 1, 'notice': None, 'total_count': 8818}, 'data': [{'id': 1, 'name': 'Bitcoin', 'symbol': 'BTC', 'slug': 'bitcoin', 'num_market_pairs': 10821, 'date_added': '2010-07-13T00:00:00.000Z', 'tags': ['mineable', 'pow', 'sha-256', 'store-of-value', 'state-channel', 'coinbase-ventures-portfolio', 'three-arrows-capital-portfolio', 'polychain-capital-portfolio', 'binance-labs-portfolio', 'blockchain-capital-portfolio', 'boostvc-portfolio', 'cms-holdings-portfolio', 'dcg-portfolio', 'dragonfly-capital-portfolio', 'electric-capital-portfolio', 'fabric-ventures-portfolio', 'framework-ventures-portfolio', 'galaxy-digital-portfolio', 'huobi-capital-portfolio', 'alameda-research-portfolio', 'a16z-portfolio', '1confirmation-portfolio', 'winklevoss-capital-portfolio', 'usv-portfolio', 'placeholder-ventures-portfolio', 'pantera-capital-portfolio', 'multicoin-capital-portfolio', 'pa
# ...

# %%
type(data)
# Out:
# dict

# %%
import pandas as pd
norm=pd.json_normalize(data['data'])

# %%
norm
# Out:
#        id           name symbol           slug  num_market_pairs  \
# 0       1        Bitcoin    BTC        bitcoin             10821
# 1    1027       Ethereum    ETH       ethereum              8428
# 2     825    Tether USDt   USDT         tether             74897
# 3    1839            BNB    BNB            bnb              2070
# 4    5426         Solana    SOL         solana               626
# ..    ...            ...    ...            ...               ...
# 95   7548          WEMIX  WEMIX          wemix                52
# 96   1659         Gnosis    GNO     gnosis-gno               169
# 97  13631  Manta Network  MANTA  manta-network                84
# 98   1042        Siacoin     SC        siacoin                95
# 99  17799         Axelar    AXL         axelar                82
#
#                   date_added  \
# 0   2010-07-13T00:00:00.000Z
# 1   2015-08-07T00:00:00.000Z
# 2   2015-02-25T00:00:00.000Z
# 3   2017-07-25T00:00:00.000Z
# 4   2020-04-10T00:00:00.000Z
# ...

# %% [markdown]
# Random Fox API without API Key

# %%
import requests

# %%
page=requests.get('https://randomfox.ca/floof')

# %%
print(page.status_code)
# Out:
# 200

# %%
print(page.text)
# Out:
# {"image":"https:\/\/randomfox.ca\/images\/103.jpg","link":"https:\/\/randomfox.ca\/?i=103"}

# %%
fox=page.json()
image=fox['image']
print(image)
# Out:
# https://randomfox.ca/images/103.jpg

# %% [markdown]
# Random Dog

# %%
page=requests.get('https://dog.ceo/api/breeds/image/random')

# %%
print(page.status_code)
# Out:
# 200

# %%
print(page.text)
# Out:
# {"message":"https:\/\/images.dog.ceo\/breeds\/retriever-curly\/n02099429_1259.jpg","status":"success"}

# %%
image=page.json()
message=image['message']
print(message)
# Out:
# https://images.dog.ceo/breeds/retriever-curly/n02099429_1259.jpg

# %% [markdown]
# Weather

# %%
page=requests.get('http://api.weatherapi.com/v1')

# %%
print(page.status_code)
# Out:
# 404

# %%
print(page.text)

# %%
image=page.json()
message=image['message']
print(message)
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/requests/models.py in json(self, **kwargs)
#     970         try:
# --> 971             return complexjson.loads(self.text, **kwargs)
#     972         except JSONDecodeError as e:
#
# /usr/lib/python3.10/json/__init__.py in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     345             parse_constant is None and object_pairs_hook is None and not kw):
# --> 346         return _default_decoder.decode(s)
#     347     if cls is None:
#
# /usr/lib/python3.10/json/decoder.py in decode(self, s, _w)
#     336         """
# --> 337         obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#     338         end = _w(s, end).end()
#
# /usr/lib/python3.10/json/decoder.py in raw_decode(self, s, idx)
#     354         except StopIteration as err:
# ...

# %%
from requests import Request, Session
from requests.exceptions import ConnectionError, Timeout, TooManyRedirects
import json

url = 'JSON: http://api.weatherapi.com/v1/current.json?key=<YOUR_API_KEY>&q=London'
parameters = {
  'start':'1',
  'limit':'100',
  'convert':'USD'
}
headers = {
  'Accepts': 'application/json',
  'X-CMC_PRO_API_KEY': '7ccaa6c0e5734849bdf71513242002',
}

session = Session()
session.headers.update(headers)

try:
  response = session.get(url, params=parameters)
  data = json.loads(response.text)
  print(data)
except (ConnectionError, Timeout, TooManyRedirects) as e:
  print(e)
# Out:
# {'cod': '200', 'message': 0, 'cnt': 40, 'list': [{'dt': 1708419600, 'main': {'temp': 263.07, 'feels_like': 256.98, 'temp_min': 263.07, 'temp_max': 265.88, 'pressure': 1031, 'sea_level': 1031, 'grnd_level': 1010, 'humidity': 97, 'temp_kf': -2.81}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04d'}], 'clouds': {'all': 100}, 'wind': {'speed': 3.5, 'deg': 191, 'gust': 6.27}, 'visibility': 10000, 'pop': 0, 'sys': {'pod': 'd'}, 'dt_txt': '2024-02-20 09:00:00'}, {'dt': 1708430400, 'main': {'temp': 265.9, 'feels_like': 260.1, 'temp_min': 265.9, 'temp_max': 268.02, 'pressure': 1029, 'sea_level': 1029, 'grnd_level': 1009, 'humidity': 92, 'temp_kf': -2.12}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04d'}], 'clouds': {'all': 100}, 'wind': {'speed': 3.84, 'deg': 184, 'gust': 7.31}, 'visibility': 10000, 'pop': 0, 'sys': {'pod': 'd'}, 'dt_txt': '2024-02-20 12:00:00'}, {'dt': 1708441200, 'main': {'temp': 265.32, 'feel
# ...

# %%
type(data)
# Out:
# dict

# %%
import pandas as pd
norm=pd.json_normalize(data['data'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-98-5d025708a352> in <cell line: 2>()
#       1 import pandas as pd
# ----> 2 norm=pd.json_normalize(data['data'])
#
# KeyError: 'data'
